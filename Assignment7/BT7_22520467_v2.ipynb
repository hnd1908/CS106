# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install colabgymrender==1.0.2
# Out:
# Requirement already satisfied: colabgymrender==1.0.2 in /usr/local/lib/python3.10/dist-packages (1.0.2)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (3.0)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (1.0.3)
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (0.25.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (4.8.0.76)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym->colabgymrender==1.0.2) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym->colabgymrender==1.0.2) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym->colabgymrender==1.0.2) (0.0.8)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (4.66.4)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (0.1.10)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (2.31.6)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (0.4.9)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio<3.0,>=2.5->moviepy->colabgymrender==1.0.2) (9.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg>=0.2.0->moviepy->colabgymrender==1.0.2) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (2024.2.2)

# %%
from colabgymrender.recorder import Recorder

# %%
# install dependencies
# !apt install chromium-browser xvfb
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# chromium-browser is already the newest version (1:85.0.4183.83-0ubuntu2.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.10).
# 0 upgraded, 0 newly installed, 0 to remove and 44 not upgraded.

# %%
env = gym.make('MountainCar-v0')
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0

while not done:
    action = env.action_space.sample()
    next_state, reward, done, info = env.step(action)
    total_reward += reward
    state = next_state

print(total_reward)
env.play()
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# -200.0
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
total_reward
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# -200.0

# %%
# # Hyperparameters
# max_epsilon = 1.0
# min_epsilon = 0.01
# max_num_steps = 50000
# epsilon_decay_intervals = 10000
# gamma = 0.99 # discount
# alpha = 5e-4 # learning rate

# memory_size = 50000
# min_replay_size = 1000
# batch_size = 32

# target_update_frequency = 1000 # target network update frequency

# Hyperparameters
# Hyperparameters
max_epsilon = 1.0
min_epsilon = 0.001
max_num_steps = 150000
epsilon_decay_intervals = 10000
gamma = 0.99 # discount
alpha = 8e-4 # learning rate

memory_size = 100000
min_replay_size = 1000
batch_size = 256

target_update_frequency = 1000 # target network update frequency
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, env):
        super(NeuralNetwork, self).__init__()

        self.network = nn.Sequential(
            nn.Linear(env.observation_space.shape[0], 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.Sigmoid(),
            nn.Linear(128, env.action_space.n)
        )

    def forward(self, state):
        return self.network(state)

    def choose_action(self, state):
        state = torch.tensor(state, dtype=torch.float32)
        q_values = self(state.unsqueeze(0)) # pytorch requires inputs in terms of batch
        best_action = torch.argmax(q_values, dim=1)[0]

        return best_action.detach().item()

# %%
def fill_memory(env):
    memory = deque(maxlen=memory_size)
    state = env.reset()
    for _ in range(min_replay_size):
        action = env.action_space.sample()
        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        memory.append(experience)
        state = next_state
        if done:
            env.reset()

    return memory

# %%
def dqn_training(env, max_num_steps, max_epsilon, min_epsilon, num_epsilon_decay_intervals, gamma, lr):
    q_net = NeuralNetwork(env)
    target_net = NeuralNetwork(env)
    target_net.load_state_dict(q_net.state_dict())
    optimizer = torch.optim.Adam(q_net.parameters(), lr=lr)

    memory = fill_memory(env)
    reward_buffer = deque(maxlen=100) # Rewards of the previous 100 episodes

    reward_per_episode = 0.0
    state = env.reset()
    all_rewards = []
    for step in range(max_num_steps):
        epsilon = np.interp(step, [0, num_epsilon_decay_intervals], [max_epsilon, min_epsilon])

        random_number = np.random.uniform(0,1)
        if random_number <= epsilon:
            action = env.action_space.sample()
        else:
            action = q_net.choose_action(state)

        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        memory.append(experience)
        reward_per_episode += reward

        state = next_state

        if done:
            state = env.reset()
            reward_buffer.append(reward_per_episode)
            all_rewards.append((step, reward_per_episode))
            reward_per_episode = 0.0


        # Take a batch of experiences from the memory
        if len(memory) >= batch_size:
            experiences = random.sample(memory, batch_size)
            states = torch.tensor([ex[0] for ex in experiences], dtype=torch.float32)
            actions = torch.tensor([ex[1] for ex in experiences], dtype=torch.int64).unsqueeze(-1)  # (batch_size,) --> (batch_size, 1)
            rewards = torch.tensor([ex[2] for ex in experiences], dtype=torch.float32).unsqueeze(-1)
            dones = torch.tensor([ex[3] for ex in experiences], dtype=torch.float32).unsqueeze(-1)
            next_states = torch.tensor([ex[4] for ex in experiences], dtype=torch.float32)

            # Compute targets using the formulation sample = r + gamma * max q(s',a')
            target_q_values = target_net(next_states)
            max_target_q_values = target_q_values.max(dim=1, keepdim=True)[0]
            targets = rewards + gamma * (1 - dones) * max_target_q_values

            # Compute loss
            q_values = q_net(states)
            action_q_values = torch.gather(input=q_values, dim=1, index=actions)
            loss = torch.nn.functional.mse_loss(action_q_values, targets)

            # Gradient descent for q-network
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Update target network
            if (step + 1) % target_update_frequency == 0:
                target_net.load_state_dict(q_net.state_dict())

        # print training results
        if (step+1) % 1000 == 0:
            average_reward = np.mean(reward_buffer)
            print(f'Episode: {len(all_rewards)} Step: {step+1} Average reward: {average_reward}')

    return all_rewards, q_net

# %%
all_rewards, q_net = dqn_training(env, max_num_steps, max_epsilon, min_epsilon, epsilon_decay_intervals, gamma, lr=alpha)
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# Episode: 5 Step: 1000 Average reward: -200.0
# Episode: 10 Step: 2000 Average reward: -200.0
# Episode: 15 Step: 3000 Average reward: -200.0
# Episode: 20 Step: 4000 Average reward: -200.0
# Episode: 25 Step: 5000 Average reward: -200.0
# Episode: 30 Step: 6000 Average reward: -200.0
# Episode: 35 Step: 7000 Average reward: -200.0
# Episode: 40 Step: 8000 Average reward: -200.0
# Episode: 45 Step: 9000 Average reward: -200.0
# Episode: 50 Step: 10000 Average reward: -200.0
# Episode: 55 Step: 11000 Average reward: -200.0
# Episode: 60 Step: 12000 Average reward: -200.0
# Episode: 65 Step: 13000 Average reward: -200.0
# Episode: 70 Step: 14000 Average reward: -200.0
# Episode: 75 Step: 15000 Average reward: -199.32
# Episode: 80 Step: 16000 Average reward: -198.8625
# Episode: 85 Step: 17000 Average reward: -198.9294117647059
# Episode: 90 Step: 18000 Average reward: -197.87777777777777
# Episode: 96 Step: 19000 Average reward: -197.08333333333334
# Episode: 102 Step: 20000 Average reward: -195.15
# Episode: 107 Step: 21000 Average reward: -194.25
# Episode: 113 Step: 22000 Average reward: -193.39
# Episode: 118 Step: 23000 Average reward: -192.68
# Episode: 124 Step: 24000 Average reward: -191.37
# Episode: 130 Step: 25000 Average reward: -189.98
# Episode: 135 Step: 26000 Average reward: -189.28
# Episode: 140 Step: 27000 Average reward: -188.62
# Episode: 146 Step: 28000 Average reward: -186.87
# Episode: 152 Step: 29000 Average reward: -184.69
# Episode: 158 Step: 30000 Average reward: -183.88
# Episode: 163 Step: 31000 Average reward: -182.01
# Episode: 170 Step: 32000 Average reward: -179.62
# Episode: 176 Step: 33000 Average reward: -178.22
# Episode: 181 Step: 34000 Average reward: -178.17
# Episode: 187 Step: 35000 Average reward: -176.88
# Episode: 193 Step: 36000 Average reward: -176.29
# Episode: 198 Step: 37000 Average reward: -176.85
# Episode: 204 Step: 38000 Average reward: -177.1
# Episode: 209 Step: 39000 Average reward: -176.66
# Episode: 214 Step: 40000 Average reward: -176.92
# Episode: 220 Step: 41000 Average reward: -177.23
# Episode: 225 Step: 42000 Average reward: -178.27
# Episode: 230 Step: 43000 Average reward: -179.13
# Episode: 235 Step: 44000 Average reward: -179.8
# Episode: 240 Step: 45000 Average reward: -180.46
# Episode: 245 Step: 46000 Average reward: -181.47
# Episode: 251 Step: 47000 Average reward: -181.82
# Episode: 256 Step: 48000 Average reward: -182.47
# Episode: 262 Step: 49000 Average reward: -183.1
# Episode: 268 Step: 50000 Average reward: -183.77
# Episode: 273 Step: 51000 Average reward: -184.45
# Episode: 278 Step: 52000 Average reward: -185.38
# Episode: 284 Step: 53000 Average reward: -185.34
# Episode: 290 Step: 54000 Average reward: -184.83
# Episode: 296 Step: 55000 Average reward: -183.95
# Episode: 302 Step: 56000 Average reward: -182.92
# Episode: 308 Step: 57000 Average reward: -183.0
# Episode: 313 Step: 58000 Average reward: -181.9
# Episode: 319 Step: 59000 Average reward: -181.71
# Episode: 324 Step: 60000 Average reward: -181.3
# Episode: 329 Step: 61000 Average reward: -181.61
# Episode: 335 Step: 62000 Average reward: -180.18
# Episode: 341 Step: 63000 Average reward: -177.83
# Episode: 347 Step: 64000 Average reward: -176.69
# Episode: 353 Step: 65000 Average reward: -176.54
# Episode: 359 Step: 66000 Average reward: -174.81
# Episode: 365 Step: 67000 Average reward: -175.27
# Episode: 371 Step: 68000 Average reward: -174.34
# Episode: 376 Step: 69000 Average reward: -173.34
# Episode: 383 Step: 70000 Average reward: -171.26
# Episode: 389 Step: 71000 Average reward: -170.81
# Episode: 396 Step: 72000 Average reward: -170.66
# Episode: 401 Step: 73000 Average reward: -171.65
# Episode: 407 Step: 74000 Average reward: -171.45
# Episode: 413 Step: 75000 Average reward: -170.97
# Episode: 419 Step: 76000 Average reward: -170.27
# Episode: 426 Step: 77000 Average reward: -166.82
# Episode: 433 Step: 78000 Average reward: -164.23
# Episode: 440 Step: 79000 Average reward: -162.4
# Episode: 447 Step: 80000 Average reward: -159.59
# Episode: 454 Step: 81000 Average reward: -157.78
# Episode: 462 Step: 82000 Average reward: -155.33
# Episode: 470 Step: 83000 Average reward: -150.48
# Episode: 477 Step: 84000 Average reward: -148.59
# Episode: 485 Step: 85000 Average reward: -147.54
# Episode: 492 Step: 86000 Average reward: -144.21
# Episode: 499 Step: 87000 Average reward: -143.98
# Episode: 509 Step: 88000 Average reward: -137.2
# Episode: 516 Step: 89000 Average reward: -133.43
# Episode: 524 Step: 90000 Average reward: -131.8
# Episode: 531 Step: 91000 Average reward: -132.79
# Episode: 538 Step: 92000 Average reward: -132.81
# Episode: 547 Step: 93000 Average reward: -131.16
# Episode: 553 Step: 94000 Average reward: -130.72
# Episode: 560 Step: 95000 Average reward: -131.58
# Episode: 569 Step: 96000 Average reward: -131.54
# Episode: 577 Step: 97000 Average reward: -131.16
# Episode: 585 Step: 98000 Average reward: -129.9
# Episode: 593 Step: 99000 Average reward: -128.86
# Episode: 601 Step: 100000 Average reward: -128.34
# Episode: 608 Step: 101000 Average reward: -130.52
# Episode: 615 Step: 102000 Average reward: -131.76
# Episode: 623 Step: 103000 Average reward: -131.2
# Episode: 631 Step: 104000 Average reward: -129.22
# Episode: 639 Step: 105000 Average reward: -129.28
# Episode: 647 Step: 106000 Average reward: -129.77
# Episode: 655 Step: 107000 Average reward: -127.53
# Episode: 662 Step: 108000 Average reward: -127.91
# Episode: 672 Step: 109000 Average reward: -126.79
# Episode: 679 Step: 110000 Average reward: -126.42
# Episode: 689 Step: 111000 Average reward: -125.25
# Episode: 697 Step: 112000 Average reward: -124.61
# Episode: 705 Step: 113000 Average reward: -123.87
# Episode: 714 Step: 114000 Average reward: -122.4
# Episode: 722 Step: 115000 Average reward: -121.47
# Episode: 730 Step: 116000 Average reward: -121.78
# Episode: 738 Step: 117000 Average reward: -120.92
# Episode: 747 Step: 118000 Average reward: -120.01
# Episode: 756 Step: 119000 Average reward: -118.43
# Episode: 764 Step: 120000 Average reward: -117.83
# Episode: 774 Step: 121000 Average reward: -117.64
# Episode: 783 Step: 122000 Average reward: -115.83
# Episode: 792 Step: 123000 Average reward: -116.78
# Episode: 801 Step: 124000 Average reward: -115.18
# Episode: 811 Step: 125000 Average reward: -114.01
# Episode: 820 Step: 126000 Average reward: -112.75
# Episode: 829 Step: 127000 Average reward: -110.2
# Episode: 839 Step: 128000 Average reward: -109.74
# Episode: 849 Step: 129000 Average reward: -107.78
# Episode: 859 Step: 130000 Average reward: -106.54
# Episode: 868 Step: 131000 Average reward: -105.98
# Episode: 878 Step: 132000 Average reward: -105.11
# Episode: 888 Step: 133000 Average reward: -104.68
# Episode: 897 Step: 134000 Average reward: -104.56
# Episode: 907 Step: 135000 Average reward: -104.14
# Episode: 917 Step: 136000 Average reward: -103.71
# Episode: 927 Step: 137000 Average reward: -102.57
# Episode: 936 Step: 138000 Average reward: -102.37
# Episode: 946 Step: 139000 Average reward: -102.35
# Episode: 956 Step: 140000 Average reward: -102.64
# Episode: 966 Step: 141000 Average reward: -102.3
# Episode: 976 Step: 142000 Average reward: -102.03
# Episode: 986 Step: 143000 Average reward: -102.18
# Episode: 995 Step: 144000 Average reward: -102.44
# Episode: 1005 Step: 145000 Average reward: -102.33
# Episode: 1014 Step: 146000 Average reward: -102.6
# Episode: 1024 Step: 147000 Average reward: -103.23
# Episode: 1034 Step: 148000 Average reward: -102.78
# Episode: 1044 Step: 149000 Average reward: -102.66
# Episode: 1053 Step: 150000 Average reward: -102.86

# %%
all_rewards = np.array(all_rewards)
plt.xlabel('Steps')
plt.ylabel('Score')
plt.plot(all_rewards[:, 0], all_rewards[:, 1])

# %%
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0
q_net.eval()

with torch.no_grad():
    while not done:
        #action = env.action_space.sample()
        action = q_net.choose_action(state)
        next_state, reward, done, info = env.step(action)
        total_reward += reward
        state = next_state

print(total_reward)
env.play()
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# -84.0
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
